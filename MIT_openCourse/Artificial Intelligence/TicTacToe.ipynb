# %% [markdown]
# Make a tic-tac toe game
#
# issues:
#
#
# ideas:
# - put the game in a function and call it when it's needed

# %%
options1 = ["x", "o", "quit", "Quit", "QUIT"]
options2 = ["y", "yes", "ye", "yh", "n", "no", "quit", "Quit", "QUIT"]
exit = ["quit", "Quit", "QUIT"]
board = ["11","12","13","21","22","23","31","32","33", "1 1", "1 2", "1 3","2 1","2 2","2 3","3 1","3 2","3 3" , "quit", "Quit", "QUIT"]
on = True

# playing the game 1v1
while on:
    A = [["11","12","13"],["21","22","23"],["31","32","33"]]
    print(A[0])
    print(A[1])
    print(A[2])
    
    x_or_o = input("Player 1, choose either 'x' or 'o': ")
    while x_or_o not in options:
        x_or_o = input("Choose either 'x' or 'o': ")
    player1 = x_or_o
    if player1 == "x":
        player2 = "o"
    elif player1 in exit:
        break
    else:
        player2 = "x"
    player = 1
    
    chosen = []
    gameover = False
    while not gameover: 
        print("To go back to main menu enter 'quit'")
        
        pos = input("Player %i, where do you want to place your marker (Input in format '#row #col')?: " %player).strip()
        while pos not in board or pos in chosen:
            pos = input("Occupied space or wrong input format '\n ").strip()
        if pos in exit:
            break
        else:
            pass
        chosen.append(pos)
        A[int(list(pos)[0])-1][int(list(pos)[-1])-1] = x_or_o
        print(A[0])
        print(A[1])
        print(A[2])
        
        # win conditions
        win = []
        # diagonal
        for i in range(3):
            win.append(A[i][i])
        if win[0] == win[1] and win[0] == win[2]:
            print("Player %s is the winner" %player)
            gameover = True
        else:
            pass
        # conjugated diag
        for i in reversed(range(3)):
            win[-(i+1)] = A[i][-(i+1)]
        if win[0] == win[1] and win[0] == win[2]:
            print("Player %s is the winner" %player)
            gameover = True
        else:
            pass
        # horizontal
        for i in range(3):
            win = []
            for j in range(3):
                win.append(A[i][j])
            if win[0] == win[1] and win[0] == win[2]:
                print("Player %s is the winner" %player)
                gameover = True
                break
            else:
                continue
        # vertical
        for i in range(3):
            win = []
            for j in range(3):
                win.append(A[j][i])
            if win[0] == win[1] and win[0] == win[2]:
                print("Player %s is the winner" %player)
                gameover = True
                break
            else:
                continue
        
        # Draw conditions
        if len(chosen) >= 7:
            print("Draw!")
            gameover = True
        
        if gameover == True:
            break
        else:
            pass
        
        if player == 1:
            x_or_o = player2
            player = 2
        else:
            x_or_o = player1
            player = 1
        
        

    play = input("Do you want to play again? [y/n] ")
    while play not in options2:
        play = input("Do you want to play again? [y/n] ")  
    if play == "y" or play == "yes":
        on = True
    else: 
        on = False

# %%
options1 = ["x", "o", "quit", "Quit", "QUIT"]
options2 = ["y", "yes", "ye", "yh", "n", "no", "quit", "Quit", "QUIT"]
exit = ["quit", "Quit", "QUIT"]
board = ["11","12","13","21","22","23","31","32","33", "1 1", "1 2", "1 3","2 1","2 2","2 3","3 1","3 2","3 3" , "quit", "Quit", "QUIT"]
on = True

# playing the game 1v1
while on:
    A = [["11","12","13"],["21","22","23"],["31","32","33"]]
    print(A[0])
    print(A[1])
    print(A[2])
    
    x_or_o = input("Player 1, choose either 'x' or 'o': ")
    while x_or_o not in options:
        x_or_o = input("Choose either 'x' or 'o': ")
    player1 = x_or_o
    if player1 == "x":
        player2 = "o"
    elif player1 in exit:
        break
    else:
        player2 = "x"
    player = 1
    
    chosen = []
    gameover = False
    while not gameover: 
        print("To go back to main menu enter 'quit'")
        
        pos = input("Player %i, where do you want to place your marker (Input in format '#row #col')?: " %player).strip()
        while pos not in board or pos in chosen:
            pos = input("Occupied space or wrong input format '\n ").strip()
        if pos in exit:
            break
        else:
            pass
        chosen.append(pos)
        A[int(list(pos)[0])-1][int(list(pos)[-1])-1] = x_or_o
        print(A[0])
        print(A[1])
        print(A[2])
        
        # win conditions
        win = []
        # diagonal
        for i in range(3):
            win.append(A[i][i])
        if win[0] == win[1] and win[0] == win[2]:
            print("Player %s is the winner" %player)
            gameover = True
        else:
            pass
        # conjugated diag
        for i in reversed(range(3)):
            win[-(i+1)] = A[i][-(i+1)]
        if win[0] == win[1] and win[0] == win[2]:
            print("Player %s is the winner" %player)
            gameover = True
        else:
            pass
        # horizontal
        for i in range(3):
            win = []
            for j in range(3):
                win.append(A[i][j])
            if win[0] == win[1] and win[0] == win[2]:
                print("Player %s is the winner" %player)
                gameover = True
                break
            else:
                continue
        # vertical
        for i in range(3):
            win = []
            for j in range(3):
                win.append(A[j][i])
            if win[0] == win[1] and win[0] == win[2]:
                print("Player %s is the winner" %player)
                gameover = True
                break
            else:
                continue
        
        # Draw conditions
        if len(chosen) >= 7:
            print("Draw!")
            gameover = True
        
        if gameover == True:
            break
        else:
            pass
        
        if player == 1:
            x_or_o = player2
            player = 2
        else:
            x_or_o = player1
            player = 1
        
        

    play = input("Do you want to play again? [y/n] ")
    while play not in options2:
        play = input("Do you want to play again? [y/n] ")  
    if play == "y" or play == "yes":
        on = True
    else: 
        on = False
