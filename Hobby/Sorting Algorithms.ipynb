# %%
import random
n = 5
arr = tuple([random.randint(1,10) for _ in range(n)])
print(list(arr))
Arr = list(arr)
# Out:
# [4, 10, 9, 3, 5]

# %% [markdown]
# ## Bubble sort $O(n^2)$
#
# ![image.png](attachment:image.png)

# %%
def bubblesort(arr):
    for j in range(len(arr)):
        for i in range(len(arr)-1):
            if arr[i]<=arr[i+1]:
                pass
            else:
                arr[i], arr[i+1] = arr[i+1], arr[i]
    return arr
print("Unsorted:",Arr)
print("Sorted:",bubblesort(Arr))
# Out:
# Unsorted: [4, 10, 9, 3, 5]
# Sorted: [3, 4, 5, 9, 10]

# %% [markdown]
# ## Quick Sort $O(n^2)$
# ![image.png](attachment:image.png)

# %%
Arr = list(arr)
print("Unsorted:",Arr)
def quicksort(arr):
    if len(arr)<=1:
        return arr
    else:
        smaller, equal, bigger = [], [], []
        pivot = arr[-1]
        #pivot = arr[0]
        #pivot = arr[random.randint(0,len(arr)-1)]
        #pivot = arr[len(arr)//2] # this is called merge sort with O(nlog(n))
        for i in arr:
            if i < pivot:
                smaller.append(i)
            elif i > pivot:
                bigger.append(i)
            else: 
                equal.append(i)
        return quicksort(smaller)+equal+quicksort(bigger)

print("Sorted:",quicksort(Arr))
# Out:
# Unsorted: [4, 10, 9, 3, 5]
# Sorted: [3, 4, 5, 9, 10]

# %% [markdown]
# ## Heap Sort
#
# ![image.png](attachment:image.png)

# %%
Arr = list(arr)
print("Unsorted:",Arr)

def heapsort(arr): # O(n**2)
    ans = []
    while len(arr)>0:
        temp = max(arr)
        ans.insert(0,temp)
        arr.remove(temp)
    return ans



def heap(arr): # O(n)
    
    def heapify(arr, n, i): # O(log(n))
        largest = i
        left= 2*i+1
        right= 2*i+2

        if left<n and arr[i] < arr[left]:
            largest = left

        if right < n and arr[largest] < arr[right]:
            largest = right

        if largest != i:
            arr[i],arr[largest] = arr[largest],arr[i]
            heapify(arr,n,largest)
            
    n = len(arr)
    for i in range(n,-1,-1):
        heapify(arr,n,i)
    for i in range(n-1,0,-1):
        arr[i],arr[0] = arr[0], arr[i]
        heapify(arr,i,0)
    return arr

# print("Sorted:", heapsort(Arr))
print("Sorted:", heap(Arr))
# Out:
# Unsorted: [4, 10, 9, 3, 5]
# Sorted: [3, 4, 5, 9, 10]

# %% [markdown]
# ## Shell Sort
#
# ![image.png](attachment:image.png)

# %%
Arr = list(arr)
print("Unsorted:",Arr)

# def shellsort(arr):


# print("Sorted:",shellsort(Arr))
# Out:
# Unsorted: [4, 10, 9, 3, 5]

# %% [markdown]
# ## Insertion Sort $O(n^2)$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Selection Sort $O(n^2)$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tree Sort $O(nlog(n))$
#
# ![image.png](attachment:image.png)
#
# Step 1: Take the elements input in an array. <br>
# Step 2: Create a Binary search tree by inserting data items from the array into the binary search tree. <br> Step 3: Perform in-order traversal on the tree to get the elements in sorted order.
